# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# /home/hafnium/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/analytics.py:108: UserWarning: unable to parse version details from package URL.
#   warnings.warn("unable to parse version details from package URL.")
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 502 Bad Gateway"
# /home/hafnium/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/analytics.py:108: UserWarning: unable to parse version details from package URL.
#   warnings.warn("unable to parse version details from package URL.")

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)
# Out:
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 04:39:10 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 04:39:13 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 04:39:13 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 04:39:13 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 04:39:13 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# * Running on local URL:  http://127.0.0.1:7862
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] HTTP Request: GET http://127.0.0.1:7862/gradio_api/startup-events "HTTP/1.1 200 OK"
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] HTTP Request: HEAD http://127.0.0.1:7862/ "HTTP/1.1 200 OK"
# * To create a public link, set `share=True` in `launch()`.
# [2025-09-30 04:39:30 +0900] [Agents] [INFO] HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 500 Internal Server Error"
# /home/hafnium/anaconda3/envs/llms/lib/python3.11/site-packages/gradio/analytics.py:108: UserWarning: unable to parse version details from package URL.
#   warnings.warn("unable to parse version details from package URL.")
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code, followed by price_is_right_final.py

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!
#
# Note that the Frontier Agent will use DeepSeek if there's a DEEPSEEK_API_KEY in your .env file, otherwise gpt-4o-mini.

# %%
# !python price_is_right_final.py
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:23 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:26 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is set up with DeepSeek
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:44 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] Use pytorch device_name: cuda:0
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:47 +0900] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] Kicking off Planning Agent
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] Kicking off Planning Agent
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-09-30 05:22:53 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-09-30 05:24:39 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 47 deals not already scraped
# [2025-09-30 05:24:39 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 47 deals not already scraped
# [2025-09-30 05:24:39 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-09-30 05:24:39 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:24:57 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $189.00
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $189.00
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  4.23it/s]
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:34 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:35 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:35 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $159.99
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $159.99
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 39.02it/s]
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $107.29
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $107.29
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $194.63
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $194.63
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $97.64
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $97.64
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:36 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 27.01it/s]
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:38 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $849.99
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $849.99
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 24.30it/s]
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $244.43
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $244.43
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $935.00
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $935.00
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $135.01
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $135.01
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:40 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $950.00
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 81.85it/s]
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:42 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $749.99
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $749.99
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|███████████████████████████████████| 1/1 [00:00<00:00, 110.38it/s]
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $528.63
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $528.63
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $816.25
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $816.25
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-183.75
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-183.75
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:44 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $699.00
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $699.00
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|███████████████████████████████████| 1/1 [00:00<00:00, 112.96it/s]
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:46 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|███████████████████████████████████| 1/1 [00:00<00:00, 204.10it/s]
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $334.41
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $334.41
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $573.91
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $573.91
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $114.91
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $114.91
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:47 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $189.00
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $189.00
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 61.69it/s]
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call deepseek-chat with context including 5 similar products
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:49 +0900] [Agents] [INFO] HTTP Request: POST https://api.deepseek.com/chat/completions "HTTP/1.1 200 OK"
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $179.00
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $179.00
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 37.72it/s]
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $342.86
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $342.86
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $179.88
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $179.88
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $79.88
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $79.88
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $135.01
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $135.01
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-09-30 05:25:51 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Samsung QN1EF 4K HDR Neo QLED Smart TVs are equipped with Vision AI technology, enhancing picture quality for an immersive viewing experience. Available in various sizes, these TVs deliver breathtaking 4K visuals and come with features like multiple HDMI inputs and smart connectivity options. A 1-year ESPN Unlimited subscription is also included with each purchase, offering additional value alongside competitive pricing.', price=799.99, url='https://www.dealnews.com/Samsung-QN1-EF-4-K-HDR-Neo-QLED-Vision-AI-Smart-TVs-2025-Up-to-1-150-off-1-yr-ESPN-Unlimited-for-free-free-shipping/21771637.html?iref=rss-c142') estimate=934.9958014269458 discount=135.00580142694582
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Samsung QN1EF 4K HDR Neo QLED Smart TVs are equipped with Vision AI technology, enhancing picture quality for an immersive viewing experience. Available in various sizes, these TVs deliver breathtaking 4K visuals and come with features like multiple HDMI inputs and smart connectivity options. A 1-year ESPN Unlimited subscription is also included with each purchase, offering additional value alongside competitive pricing.', price=799.99, url='https://www.dealnews.com/Samsung-QN1-EF-4-K-HDR-Neo-QLED-Vision-AI-Smart-TVs-2025-Up-to-1-150-off-1-yr-ESPN-Unlimited-for-free-free-shipping/21771637.html?iref=rss-c142') estimate=934.9958014269458 discount=135.00580142694582
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] Kicking off Planning Agent
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] Kicking off Planning Agent
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-09-30 05:25:52 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 46 deals not already scraped
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent received 46 deals not already scraped
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] Retrying request to /chat/completions in 0.419954 seconds
# [2025-09-30 05:27:32 +0900] [Agents] [INFO] Retrying request to /chat/completions in 0.419954 seconds
# ^C
# Keyboard interruption in main thread... closing server.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">But wait!! There's more..</h2>
#             <span style="color:#900;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment3/lab1 is a neural network implementation of the pricer in pure PyTorch. It does pretty well..<br/>
#             And if you look in my repo <a href="https://github.com/ed-donner/agentic">Agentic</a> in the workshop folder is the same Agent project taken further. There's a new version of the PlanningAgent called AutonomousPlanningAgent that uses multiple Tools, and a MessagingAgent that uses claude-3.7 to write texts. The AutonomousPlanningAgent uses the fantastic OpenAI Agents SDK and the mighty MCP protocol from Anthropic.<br/>
#             If you're intrigued by Agents and MCP, and would like to learn more, then I also have a <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">companion course called the Complete Agentic AI Engineering Course</a> that might interest you (if you haven't had enough of me by now!!), and also another course for leaders and founders looking to build a valuable business with LLMs.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
